# %%
import sys
import torch
from config import SimulationConfig, PersonalityConfig, ModelConfig
from questionbank import QuestionBank
from retriever import RetrieverModel, QuestionRetriever
from storememory import MemoryStore
from timestamp import TimestampManager
from models.teacheragent import TeacherAgent
from models.studentlearning import StudentLearningAgent
from models.studentexam import StudentExamAgent
from environments.learningloop import LearningLoop
from environments.examloop import ExamLoop
from evaluation.metrics import AnswerEvaluator
from main import run_simulation, set_seed

print("All modules imported successfully")
print(f"CUDA available: {torch.cuda.is_available()}")
# Out:
# All modules imported successfully
# CUDA available: True

# %%
print("="*80)
print("DATASET INFORMATION PREVIEW")
print("="*80)

qb = QuestionBank()

print(f"\nTotal questions in database: {len(qb.df)}")
print(f"\nAvailable categories: {len(qb.categories)}")

print("\nCategory breakdown (60% train / 40% test split):")
print("-" * 80)
print(f"{'Category':<25} {'Total':<10} {'Train (60%)':<15} {'Test (40%)':<15}")
print("-" * 80)

category_info = []
for category in sorted(qb.categories):
    total = len(qb.get_all_ids_by_category(category))
    train = int(total * 0.6)
    test = total - train
    category_info.append({
        'category': category,
        'total': total,
        'train': train,
        'test': test
    })
    print(f"{category:<25} {total:<10} {train:<15} {test:<15}")

print("-" * 80)

print("\n" + "="*80)
print("AVAILABLE PERSONALITIES")
print("="*80)

personalities = [
    ('get_high_openness()', 'High Openness - Curious, explores different methods'),
    ('get_high_conscientiousness()', 'High Conscientiousness - Organized, persistent'),
    ('get_high_extraversion()', 'High Extraversion - Enjoys teacher interaction'),
    ('get_high_agreeableness()', 'High Agreeableness - Cooperative, receptive'),
    ('get_high_neuroticism()', 'High Neuroticism - Anxious, seeks reassurance')
]

for name, desc in personalities:
    print(f"\nPersonalityConfig.{name}")
    print(f"  → {desc}")
# Out:
# ================================================================================
# DATASET INFORMATION PREVIEW
# ================================================================================
#
# Total questions in database: 3044
#
# Available categories: 4
#
# Category breakdown (60% train / 40% test split):
# --------------------------------------------------------------------------------
# Category                  Total      Train (60%)     Test (40%)
# --------------------------------------------------------------------------------
# Algebra                   1341       804             537
# Counting & Probability    547        328             219
# Geometry                  672        403             269
# Number Theory             484        290             194
# --------------------------------------------------------------------------------
#
# ================================================================================
# AVAILABLE PERSONALITIES
# ================================================================================
#
# PersonalityConfig.get_high_openness()
#   → High Openness - Curious, explores different methods
#
# PersonalityConfig.get_high_conscientiousness()
#   → High Conscientiousness - Organized, persistent
#
# PersonalityConfig.get_high_extraversion()
#   → High Extraversion - Enjoys teacher interaction
#
# PersonalityConfig.get_high_agreeableness()
#   → High Agreeableness - Cooperative, receptive
#
# PersonalityConfig.get_high_neuroticism()
#   → High Neuroticism - Anxious, seeks reassurance

# %%
config = SimulationConfig(
    random_seed=42,
    exam_topic="Algebra"
)
config.model_config.model_type = "local"
config.learning_config.learning_rounds = 100 #可以设置学习多少轮，但agent不一定都真的选择学习
config.exam_config.num_questions = 50 #可以设置考试多少题
config.personality = PersonalityConfig.get_high_openness()

print(f"Configuration:")
print(f"  Personality: {config.personality.name}")
print(f"  Topic: {config.exam_topic}")
print(f"  Learning rounds: {config.learning_config.learning_rounds}")
print(f"  Exam questions: {config.exam_config.num_questions}")
print(f"  Random seed: {config.random_seed}")
# Out:
# Using LOCAL model
# Detected 2 GPU(s)
#   LLM (Llama3) -> cuda:0
#   Retriever -> cuda:1
# Configuration:
#   Personality: high_openness
#   Topic: Algebra
#   Learning rounds: 100
#   Exam questions: 50
#   Random seed: 42

# %%
config = SimulationConfig(
    random_seed=42,
    exam_topic="Geometry",# Algebra Geometry Counting & Probability Number Theory
    model_config=ModelConfig(model_type="api") 
)

config.learning_config.learning_rounds = 1 
config.exam_config.num_questions = 1


#config.personality = PersonalityConfig.get_high_openness()
#config.personality = PersonalityConfig.get_high_conscientiousness()  
#config.personality = PersonalityConfig.get_high_extraversion()   
config.personality = PersonalityConfig.get_high_agreeableness()    
#config.personality = PersonalityConfig.get_high_neuroticism()     

print(f"Configuration:")
print(f"  Model type: {config.model_config.model_type}")
print(f"  Personality: {config.personality.name}")
print(f"  Topic: {config.exam_topic}")
print(f"  Learning rounds: {config.learning_config.learning_rounds}")
print(f"  Exam questions: {config.exam_config.num_questions}")
print(f"  Random seed: {config.random_seed}")
# Out:
# Using API model: gpt-oss-120b
#   API base URL: https://api.ai.it.ufl.edu
# Configuration:
#   Model type: api
#   Personality: high_agreeableness
#   Topic: Geometry
#   Learning rounds: 1
#   Exam questions: 1
#   Random seed: 42

# %%
results = run_simulation(config, config.personality)

print("\n=== Learning Summary ===")
print(f"Total memories: {results['learning_summary']['total_memories']}")
print(f"Action counts: {results['learning_summary']['action_counts']}")
print(f"Learning timestamp: {results['learning_summary']['final_timestamp']}")

print("\n=== Exam Summary ===")
print(f"Accuracy: {results['exam_summary']['accuracy']:.4f}")
print(f"Correct: {results['exam_summary']['correct_count']}/{results['exam_summary']['total_questions']}")
print(f"Exam timestamp: {results['exam_summary']['final_timestamp']}")

#accuracy calculation has some errors, use macro F1 as the final result
print(f"Micro F1: {results['metrics']['micro_f1']:.4f}")
print(f"Macro F1: {results['metrics']['macro_f1']:.4f}")
print(f"Micro Precision: {results['metrics']['micro_precision']:.4f}")
print(f"Micro Recall: {results['metrics']['micro_recall']:.4f}")
print(f"Exam results: output/{config.exam_topic}/agent_{config.personality.name}_lr{config.learning_config.learning_rounds}.csv")
print(f"Memory: memory/agent_{config.personality.name}_lr{config.learning_config.learning_rounds}.json")
print(f"Final results: results/result_{config.personality.name}_lr{config.learning_config.learning_rounds}.csv")
# Out:
# Using API model: gpt-oss-120b
# ================================================================================
# Starting simulation: high_agreeableness, Topic: Geometry
# ================================================================================
# Loaded question bank with 7 categories
# Split questions: 424 training, 284 testing
# Initializing retriever model...
# Building question retriever...
# Loaded embeddings for 708 questions from cache
# Loading LLM...
# Initializing teacher agent...
# Initializing student memory and timestamp...
# Initializing student agents...
#
# ================================================================================
# LEARNING PHASE
# ================================================================================
# Round 1/1 - Action: ask_teacher, Timestamp: 3
#
# ================================================================================
# EXAM PHASE
# ================================================================================
# Question 1/1 - Correct: True, Timestamp: 5
#
# ================================================================================
# CALCULATING METRICS
# ================================================================================
#
# Accuracy: 1.0000
# Micro F1: 0.5714
# Macro F1: 1.0000
#
# ================================================================================
# SAVING RESULTS
# ================================================================================
# Exam results saved to output/Geometry/agent_high_agreeableness_lr1.csv
# Memory and interaction logs saved to memory/Geometry/agent_high_agreeableness_lr1.json
# Final results saved to results/Geometry/result_lr1.csv
#
# ================================================================================
# SIMULATION COMPLETED
# ================================================================================
#
# === Learning Summary ===
# Total memories: 1
# Action counts: {'self_study': 0, 'ask_teacher': 1, 'skip': 0}
# Learning timestamp: 3
#
# === Exam Summary ===
# Accuracy: 1.0000
# Correct: 1/1
# Exam timestamp: 5
# Micro F1: 0.5714
# Macro F1: 1.0000
# Micro Precision: 1.0000
# Micro Recall: 0.4000
# Exam results: output/Geometry/agent_high_agreeableness_lr1.csv
# Memory: memory/agent_high_agreeableness_lr1.json
# Final results: results/result_high_agreeableness_lr1.csv
